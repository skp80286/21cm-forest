# %%
import glob
import PS1D as ps1d
import F21DataLoader as dl
import f21_predict_base as base
import plot_results as pltr
import F21Stats as f21stats

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


import matplotlib as mpl
import matplotlib.pyplot as plt   # data visualization
import seaborn as sns             # statistical data visualization
import matplotlib.colors as clr

import logging

import torch

import importlib
import glob

importlib.reload(ps1d)
importlib.reload(dl)
importlib.reload(base)
importlib.reload(f21stats)

logger = logging.getLogger(__name__)

def load_dataset(datafiles, psbatchsize=100, ps_bins=None, limitsamplesize=None, use_new_ps_calc=False):
    # Create processor with desired number of worker threads
    processor = dl.F21DataLoader(max_workers=1, psbatchsize=psbatchsize, skip_ps=False, ps_bins=None, limitsamplesize=limitsamplesize, scale_ps=True, use_new_ps_calc=use_new_ps_calc)#, limitsamplesize=4)
        
    # Process all files and get results 
    results = processor.process_all_files(datafiles)
        
    # Access results
    #print(f'{results.keys()}')
    all_ks = results['ks']
    all_los = results['los']
    all_freq = results['freq_axis']
    all_ps = results['ps']

    #print(f"all_los.shape={all_los.shape}, all_ps.shape={all_ps.shape}, all_ks.shape={all_ks.shape}")
    #all_ps, all_ks = calculate_dimensionless_power_spectrum(all_los, all_freq[0])
    #print(f"all_los.shape={all_los.shape}, all_ps.shape={all_ps.shape}, all_ks.shape={all_ks.shape}")

    #ps_std = results['ps_std']
    #ps_plus_std = all_ps + ps_std
    #ps_minus_std = all_ps - ps_std
    all_params = results['params']
    #plot_los(all_ps[0], freq_axis)
    """
    print(f"sample ks:{all_ks[0]}")
    print(f"sample ps:{all_ps[0,:]}")
    print(f"sample params:{all_params[0]}")
    print(f"sample los:{all_los[0]}")
    print(f"sample freq:{all_freq}")
    """
    #base.plot_los(all_los[:1], all_freq[0,:], showplots=True, saveplots = False, label=f"{all_params[0]}")
    #base.plot_power_spectra(all_ps[:1], all_ks[:1], all_params[:1], showplots=True, saveplots = False, label=f"{all_params[0]}")

    print(f"\Loaded LoS data shape: {all_los.shape}")
    print(f"Loaded data: parameters shape: {all_params.shape}")
    return (all_params, all_freq, all_los, all_ps, all_ks)


def logbin_power_spectrum_by_k(ks, ps):
    print(f"logbin_power_spectrum_by_k: original ks: {ks[0,:5]} .. {ks[0,-5:]}")
    print(f"original ps: {ps[0,:5]}..{ps[0,-5:]}")

    d_log_k_bins = 0.25
    log_k_bins = np.arange(-7.0-d_log_k_bins/2.,-3.+d_log_k_bins/2.,d_log_k_bins)

    k_bins = np.power(10.,log_k_bins)
    k_bins_cent = np.power(10.,log_k_bins+d_log_k_bins/2.)[:-1]
    print(k_bins_cent)

    binlist=np.zeros((ps.shape[0], len(k_bins_cent)))
    pslist=np.zeros((ps.shape[0], len(k_bins_cent)))
    for i, (row_ks, row_ps) in enumerate(zip(ks, ps)):
      for l in range(len(k_bins_cent)):
        mask = (row_ks >= k_bins[l]) & (row_ks < k_bins[l+1])
        # If any values fall in this bin, take their mean
        if np.any(mask):
            pslist[i,l] = np.mean(row_ps[mask])
        else:
            pslist[i,l] = 0.
        binlist[i,l] = k_bins_cent[l]

    print(f"logbin_power_spectrum_by_k: final ks: {binlist[0,:5]}..{binlist[0,-5:]}")
    print(f"final ps: {pslist[0,:5]}..{pslist[0,-5:]}")
    return binlist, pslist


def plot(ps_set, ks, title, labels, xscale='log', yscale='log',marker='o', alpha=1):
    print(f"shapes: {ps_set.shape},{ks.shape}")

    base.initplt()
    plt.title(f'{title}')
    if len(ps_set.shape) > 1:
        for i, ps in enumerate(ps_set):
            if labels is not None: label = labels[i]
            row_ks = None
            if ks is not None:
                if len(ks.shape) > 1: row_ks = ks[i]
                else: row_ks = ks
            plt.plot(row_ks*1e6, ps, label=label, marker=marker, alpha=alpha)
    else:
        row_ks = None
        if ks is not None:
                if len(ks.shape) > 1: row_ks = ks[i]
                else: row_ks = ks
        plt.plot(ks*1e6, ps, label=label, marker=marker, alpha=alpha)
        #plt.scatter(ks[1:]*1e6, ps[1:], label=label)
    plt.xscale(xscale)
    plt.yscale(yscale)
    plt.xlabel(r'k (Hz$^{-1}$)')
    plt.ylabel(r'$kP_{21}$')
    plt.legend()
    plt.show()


colorlabels=[r'$\langle x_{HI}\rangle$', r'$log_{10}(f_X)$']
colormaps=[plt.cm.viridis, plt.cm.viridis]
def plot_power_spectra(ps, ks, params, psn=None, colorind=1, output_dir=".", showplots=False, saveplots=True, label="", scale='log', markers=False):
    print(f"ps.shape={ps.shape}, ks.shape={ks.shape}, paramas.shape={params.shape}")
    #logger.info(f'shapes ps:{ps.shape} ks:{ks.shape}')
    base.initplt()
    fig, ax = plt.subplots(nrows=1, ncols=1) 

    if len(ks.shape) > 1: ks_axis = ks[0] 
    else: ks_axis=ks

    # plot the noise
    if psn is not None: 
        if len(psn.shape) > 1:
            #for i in range(psn.shape[0]):
            #    ax.scatter(ks[0,1:]*1e6, psn[i, 1:], c='red',alpha=0.1)
            # Calculate mean and standard deviation of psn
            psn_mean = np.mean(psn[:,1:], axis=0)
            psn_std = np.std(psn[:,1:], axis=0)

            # Plot the mean as a dotted red line
            ax.plot(ks_axis[1:]*1e6, psn_mean, color='red', linestyle='--', alpha=1, label='Mean Noise')

            # Add the shaded region for 1 standard deviation
            ax.fill_between(ks_axis[1:] * 1e6, psn_mean - psn_std, psn_mean + psn_std, color='red', alpha=0.3, label='Noise: 1 Std Dev')
            ax.fill_between(ks_axis[1:] * 1e6, psn_mean - 2*psn_std, psn_mean + 2*psn_std, color='red', alpha=0.1, label='Noise: 2 Std Dev')
        else:
            ax.plot(ks_axis[1:]*1e6, psn[1:], color='red', linestyle='--', alpha=1, label='Noise')
    alpha = base.decide_alpha(len(ps))
    print(f"Params: {params.shape}")
    print(f"Params: {params[0:2]}")
    coloraxs = params[:,colorind]
    mincoloraxs = min(coloraxs)
    maxcoloraxs = max(coloraxs)
    print(f"min-max range: {mincoloraxs}-{maxcoloraxs}")
    if markers: marker='o' 
    else: marker = None

    sm = plt.cm.ScalarMappable(cmap=colormaps[colorind], norm=clr.Normalize(vmin=mincoloraxs, vmax=maxcoloraxs))
    cbar = plt.colorbar(sm, ax=ax, label=colorlabels[colorind])

    plt.title('Power spectra ' + label)    
    if scale == 'log': 
        ax.set_xscale('log')
        ax.set_yscale('log')

    for i, (row_ps, row_coloraxs) in enumerate(zip(ps, coloraxs)):
        color=sm.to_rgba(row_coloraxs)
        #if i%1000==0: print(f"color mapping: {row_coloraxs} : {color}")
        ax.plot(ks_axis[1:]*1e6, row_ps[1:], linewidth=0.5, color=color, alpha=alpha, marker= marker)
        #ax.set_yscale('log')
        #if i> 10: break
        # Plot noise curve

    plt.legend()
    plt.xlabel(r"k (Hz$^{-1}$)")
    plt.ylabel("$kP_{21}$")
    #plt.ylim((1e-22, 1e-2))
    plt.xticks(fontsize=18)
    plt.yticks(fontsize=18)
    
    if showplots: plt.show()
    if saveplots: plt.savefig(f"{output_dir}/power_spectra.png")
    plt.close()
# Out:
# <>:63: SyntaxWarning: invalid escape sequence '\L'
# <>:63: SyntaxWarning: invalid escape sequence '\L'
# /var/folders/wz/tf9bd1d17kxcg2r9f2875tv00000gn/T/ipykernel_10416/4033668527.py:63: SyntaxWarning: invalid escape sequence '\L'
#   print(f"\Loaded LoS data shape: {all_los.shape}")

# %%
import glob
files10so=glob.glob("../data/21cmFAST_los/F21_noisy/F21_signalonly_21cmFAST_200Mpc_z6.0_fX-1.00_xHI*_8kHz*.dat")
# Load 10 los from each so and sn file, aggregate as 1 from each file
params10so, freq10so, los10so, ps10so, ks10so = load_dataset(files10so, psbatchsize=10, limitsamplesize=10, ps_bins=None)
ks10so_bin, ps10so_bin = logbin_power_spectrum_by_k(ks10so, ps10so)

files10sn=glob.glob("../data/21cmFAST_los/F21_noisy/F21_noisy_21cmFAST_200Mpc_z6.0_fX-1.00_xHI*_uGMRT_8kHz_t500h*.dat")
params10sn, freq10sn, los10sn, ps10sn, ks10sn = load_dataset(files10sn, psbatchsize=10, limitsamplesize=10, ps_bins=None)
ks10sn_bin, ps10sn_bin = logbin_power_spectrum_by_k(ks10sn, ps10sn)

# load 1000 los from no file
(paramsn, freqn, losn, psn, ksn) = load_dataset(["../data/21cmFAST_los/F21_noisy/F21_noiseonly_21cmFAST_200Mpc_z6.0_uGMRT_8kHz_t500h_Smin64.2mJy_alphaR-0.44.dat"], psbatchsize=1, limitsamplesize=None)
print(f"psn_bin.shape={psn.shape}")
(paramsn, freqn, losn, psn_b10, ksn_b10) = load_dataset(["../data/21cmFAST_los/F21_noisy/F21_noiseonly_21cmFAST_200Mpc_z6.0_uGMRT_8kHz_t500h_Smin64.2mJy_alphaR-0.44.dat"], psbatchsize=10, limitsamplesize=None)
print(f"psn_bin_b10.shape={psn_b10.shape}")
ksn_bin, psn_bin = logbin_power_spectrum_by_k(ksn, psn)
psn_bin_mean = np.mean(psn_bin, axis=0)
ksn_bin_b10, psn_bin_b10 = logbin_power_spectrum_by_k(ksn_b10, psn_b10)
# Out:
# \Loaded LoS data shape: (21, 2762)
# Loaded data: parameters shape: (21, 2)
# logbin_power_spectrum_by_k: original ks: [0.00000000e+00 2.84444178e-07 5.68888357e-07 8.53332535e-07
#  1.13777671e-06] .. [0.00039168 0.00039196 0.00039225 0.00039253 0.00039282]
# original ps: [0.00000000e+00 3.22238865e-09 5.90462046e-09 7.70378596e-09
#  2.06206107e-08]..[1.17019596e-08 1.10426587e-08 1.15215794e-08 1.79468709e-08
#  2.19383506e-08]
# [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06 1.77827941e-06 3.16227766e-06 5.62341325e-06
#  1.00000000e-05 1.77827941e-05 3.16227766e-05 5.62341325e-05
#  1.00000000e-04 1.77827941e-04 3.16227766e-04 5.62341325e-04]
# logbin_power_spectrum_by_k: final ks: [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06]..[5.62341325e-05 1.00000000e-04 1.77827941e-04 3.16227766e-04
#  5.62341325e-04]
# final ps: [0.00000000e+00 0.00000000e+00 3.22238865e-09 5.90462046e-09
#  1.41621983e-08]..[2.33533778e-08 2.38050421e-08 2.21945252e-08 1.65898314e-08
#  0.00000000e+00]
# \Loaded LoS data shape: (21, 2762)
# Loaded data: parameters shape: (21, 2)
# logbin_power_spectrum_by_k: original ks: [0.00000000e+00 2.84444178e-07 5.68888357e-07 8.53332535e-07
#  1.13777671e-06] .. [0.00039168 0.00039196 0.00039225 0.00039253 0.00039282]
# original ps: [0.00000000e+00 2.39853004e-08 7.88827678e-08 1.19649511e-07
#  1.55914267e-07]..[4.24802981e-05 2.49680960e-05 3.14100421e-05 5.30403925e-05
#  5.13800649e-05]
# [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06 1.77827941e-06 3.16227766e-06 5.62341325e-06
#  1.00000000e-05 1.77827941e-05 3.16227766e-05 5.62341325e-05
#  1.00000000e-04 1.77827941e-04 3.16227766e-04 5.62341325e-04]
# logbin_power_spectrum_by_k: final ks: [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06]..[5.62341325e-05 1.00000000e-04 1.77827941e-04 3.16227766e-04
#  5.62341325e-04]
# final ps: [0.00000000e+00 0.00000000e+00 2.39853004e-08 7.88827678e-08
#  1.37781889e-07]..[6.50124252e-06 1.19115634e-05 2.08213464e-05 3.45701276e-05
#  0.00000000e+00]
# \Loaded LoS data shape: (1000, 2762)
# Loaded data: parameters shape: (1000, 2)
# psn_bin.shape=(1000, 1382)
# \Loaded LoS data shape: (100, 2762)
# Loaded data: parameters shape: (100, 2)
# psn_bin_b10.shape=(100, 1382)
# logbin_power_spectrum_by_k: original ks: [0.00000000e+00 2.84444178e-07 5.68888357e-07 8.53332535e-07
#  1.13777671e-06] .. [0.00039168 0.00039196 0.00039225 0.00039253 0.00039282]
# original ps: [0.00000000e+00 7.70469600e-09 2.69660970e-08 2.73720698e-08
#  5.60970189e-08]..[7.98355340e-05 4.79065112e-06 6.40000403e-05 9.14676780e-06
#  1.05871851e-05]
# [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06 1.77827941e-06 3.16227766e-06 5.62341325e-06
#  1.00000000e-05 1.77827941e-05 3.16227766e-05 5.62341325e-05
#  1.00000000e-04 1.77827941e-04 3.16227766e-04 5.62341325e-04]
# logbin_power_spectrum_by_k: final ks: [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06]..[5.62341325e-05 1.00000000e-04 1.77827941e-04 3.16227766e-04
#  5.62341325e-04]
# final ps: [0.00000000e+00 0.00000000e+00 7.70469600e-09 2.69660970e-08
#  4.17345443e-08]..[7.08526278e-06 1.15160696e-05 1.97135356e-05 3.53448713e-05
#  0.00000000e+00]
# logbin_power_spectrum_by_k: original ks: [0.00000000e+00 2.84444178e-07 5.68888357e-07 8.53332535e-07
#  1.13777671e-06] .. [0.00039168 0.00039196 0.00039225 0.00039253 0.00039282]
# original ps: [0.00000000e+00 1.89833367e-08 5.40050994e-08 6.13336792e-08
#  7.31992029e-08]..[5.44844136e-05 7.72601210e-05 4.73686679e-05 5.89298851e-05
#  2.74100036e-05]
# [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06 1.77827941e-06 3.16227766e-06 5.62341325e-06
#  1.00000000e-05 1.77827941e-05 3.16227766e-05 5.62341325e-05
#  1.00000000e-04 1.77827941e-04 3.16227766e-04 5.62341325e-04]
# logbin_power_spectrum_by_k: final ks: [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06]..[5.62341325e-05 1.00000000e-04 1.77827941e-04 3.16227766e-04
#  5.62341325e-04]
# final ps: [0.00000000e+00 0.00000000e+00 1.89833367e-08 5.40050994e-08
#  6.72664410e-08]..[6.66974799e-06 1.20490708e-05 2.12149394e-05 3.66039005e-05
#  0.00000000e+00]

# %%
print(freq10so)
print(freq10sn)
print(freqn)
# Out:
# [[2.0302221e+08 2.0303021e+08 2.0303821e+08 ... 2.2509555e+08
#   2.2510355e+08 2.2511155e+08]
#  [2.0302221e+08 2.0303021e+08 2.0303821e+08 ... 2.2509555e+08
#   2.2510355e+08 2.2511155e+08]
#  [2.0302221e+08 2.0303021e+08 2.0303821e+08 ... 2.2509555e+08
#   2.2510355e+08 2.2511155e+08]
#  ...
#  [2.0302221e+08 2.0303021e+08 2.0303821e+08 ... 2.2509555e+08
#   2.2510355e+08 2.2511155e+08]
#  [2.0302221e+08 2.0303021e+08 2.0303821e+08 ... 2.2509555e+08
#   2.2510355e+08 2.2511155e+08]
#  [2.0302221e+08 2.0303021e+08 2.0303821e+08 ... 2.2509555e+08
#   2.2510355e+08 2.2511155e+08]]
# [[2.0302221e+08 2.0303021e+08 2.0303821e+08 ... 2.2509555e+08
#   2.2510355e+08 2.2511155e+08]
#  [2.0302221e+08 2.0303021e+08 2.0303821e+08 ... 2.2509555e+08
#   2.2510355e+08 2.2511155e+08]
#  [2.0302221e+08 2.0303021e+08 2.0303821e+08 ... 2.2509555e+08
#   2.2510355e+08 2.2511155e+08]
#  ...
#  [2.0302221e+08 2.0303021e+08 2.0303821e+08 ... 2.2509555e+08
#   2.2510355e+08 2.2511155e+08]
#  [2.0302221e+08 2.0303021e+08 2.0303821e+08 ... 2.2509555e+08
#   2.2510355e+08 2.2511155e+08]
#  [2.0302221e+08 2.0303021e+08 2.0303821e+08 ... 2.2509555e+08
#   2.2510355e+08 2.2511155e+08]]
# [[2.0302221e+08 2.0303021e+08 2.0303821e+08 ... 2.2509555e+08
#   2.2510355e+08 2.2511155e+08]
#  [2.0302221e+08 2.0303021e+08 2.0303821e+08 ... 2.2509555e+08
#   2.2510355e+08 2.2511155e+08]
#  [2.0302221e+08 2.0303021e+08 2.0303821e+08 ... 2.2509555e+08
#   2.2510355e+08 2.2511155e+08]
#  ...
#  [2.0302221e+08 2.0303021e+08 2.0303821e+08 ... 2.2509555e+08
#   2.2510355e+08 2.2511155e+08]
#  [2.0302221e+08 2.0303021e+08 2.0303821e+08 ... 2.2509555e+08
#   2.2510355e+08 2.2511155e+08]
#  [2.0302221e+08 2.0303021e+08 2.0303821e+08 ... 2.2509555e+08
#   2.2510355e+08 2.2511155e+08]]

# %%
import glob
files20so=glob.glob("../data/21cmFAST_los/F21_noisy/F21_signalonly_21cmFAST_200Mpc_z6.0_fX-2.00_xHI*_8kHz*.dat")
# Load 10 los from each so and sn file, aggregate as 1 from each file
params20so, freq20so, los20so, ps20so, ks20so = load_dataset(files20so, psbatchsize=10, limitsamplesize=10, ps_bins=None)
ks20so_bin, ps20so_bin = logbin_power_spectrum_by_k(ks20so, ps20so)

files20sn=glob.glob("../data/21cmFAST_los/F21_noisy/F21_noisy_21cmFAST_200Mpc_z6.0_fX-2.00_xHI*_uGMRT_8kHz_t500h*.dat")
params20sn, freq20sn, los20sn, ps20sn, ks20sn = load_dataset(files20sn, psbatchsize=10, limitsamplesize=10, ps_bins=None)
ks20sn_bin, ps20sn_bin = logbin_power_spectrum_by_k(ks20sn, ps20sn)
# Out:
# \Loaded LoS data shape: (21, 2762)
# Loaded data: parameters shape: (21, 2)
# logbin_power_spectrum_by_k: original ks: [0.00000000e+00 2.84444178e-07 5.68888357e-07 8.53332535e-07
#  1.13777671e-06] .. [0.00039168 0.00039196 0.00039225 0.00039253 0.00039282]
# original ps: [0.00000000e+00 1.30416009e-07 2.84020303e-07 3.57163155e-07
#  5.39731419e-07]..[1.32709031e-06 1.09601204e-06 1.11807092e-06 6.82911396e-07
#  6.94376357e-07]
# [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06 1.77827941e-06 3.16227766e-06 5.62341325e-06
#  1.00000000e-05 1.77827941e-05 3.16227766e-05 5.62341325e-05
#  1.00000000e-04 1.77827941e-04 3.16227766e-04 5.62341325e-04]
# logbin_power_spectrum_by_k: final ks: [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06]..[5.62341325e-05 1.00000000e-04 1.77827941e-04 3.16227766e-04
#  5.62341325e-04]
# final ps: [0.00000000e+00 0.00000000e+00 1.30416009e-07 2.84020303e-07
#  4.48447287e-07]..[1.37508570e-06 1.25486720e-06 1.08901174e-06 1.12914149e-06
#  0.00000000e+00]
# \Loaded LoS data shape: (21, 2762)
# Loaded data: parameters shape: (21, 2)
# logbin_power_spectrum_by_k: original ks: [0.00000000e+00 2.84444178e-07 5.68888357e-07 8.53332535e-07
#  1.13777671e-06] .. [0.00039168 0.00039196 0.00039225 0.00039253 0.00039282]
# original ps: [0.00000000e+00 8.12460776e-07 1.11564892e-06 1.11605275e-06
#  4.46791576e-06]..[4.39452020e-05 2.71283739e-05 4.23422704e-05 5.02161211e-05
#  7.62941529e-05]
# [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06 1.77827941e-06 3.16227766e-06 5.62341325e-06
#  1.00000000e-05 1.77827941e-05 3.16227766e-05 5.62341325e-05
#  1.00000000e-04 1.77827941e-04 3.16227766e-04 5.62341325e-04]
# logbin_power_spectrum_by_k: final ks: [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06]..[5.62341325e-05 1.00000000e-04 1.77827941e-04 3.16227766e-04
#  5.62341325e-04]
# final ps: [0.00000000e+00 0.00000000e+00 8.12460776e-07 1.11564892e-06
#  2.79198425e-06]..[1.53064422e-05 1.99669630e-05 2.85599870e-05 4.14805631e-05
#  0.00000000e+00]

# %% [markdown]
# diml_psn, diml_freqn = calculate_dimensionless_power_spectrum(losn, freqn[0], "Noise")
# diml_ps10sn, diml_freq10sn = calculate_dimensionless_power_spectrum(los10sn, freq10sn[0], "Signal+Noise")
# diml_ps10so, diml_freq10so = calculate_dimensionless_power_spectrum(los10so, freq10so[0], "Noiseless Signal")

# %%
# Noise subtraction
ps10_noisesub = ps10sn_bin - psn_bin[0]
ps10_noisesub_b10 = ps10sn_bin - psn_bin_b10[0]
ps10_noisesub_mean = ps10sn_bin - psn_bin_mean

# %%
plot_power_spectra(ps10sn_bin, ks10sn_bin, params10sn, psn_bin, 0, showplots=True, saveplots=False, markers=True, label='Against Noise at logfX=-1.0')
plot_power_spectra(ps20sn_bin, ks20sn_bin, params20sn, psn_bin, 0, showplots=True, saveplots=False, markers=True, label='Against Noise at logfX=-2.0')
plot_power_spectra(ps10sn_bin, ks10sn_bin, params10sn, psn_bin_b10, 0, showplots=True, saveplots=False, markers=True, label='Against Batched Noise at logfX=-1.0')
plot_power_spectra(ps20sn_bin, ks20sn_bin, params20sn, psn_bin_b10, 0, showplots=True, saveplots=False, markers=True, label='Against Batched Noise at logfX=-2.0')
# Out:
# ps.shape=(21, 16), ks.shape=(21, 16), paramas.shape=(21, 2)
# Params: (21, 2)
# Params: [[ 0.30353674 -1.        ]
#  [ 0.25006887 -1.        ]]
# min-max range: 0.004162702709436417-0.9957664012908936
# ps.shape=(21, 16), ks.shape=(21, 16), paramas.shape=(21, 2)
# Params: (21, 2)
# Params: [[ 0.52103174 -2.        ]
#  [ 0.10843496 -2.        ]]
# min-max range: 0.004337502643465996-0.9993957877159119
# ps.shape=(21, 16), ks.shape=(21, 16), paramas.shape=(21, 2)
# Params: (21, 2)
# Params: [[ 0.30353674 -1.        ]
#  [ 0.25006887 -1.        ]]
# min-max range: 0.004162702709436417-0.9957664012908936
# ps.shape=(21, 16), ks.shape=(21, 16), paramas.shape=(21, 2)
# Params: (21, 2)
# Params: [[ 0.52103174 -2.        ]
#  [ 0.10843496 -2.        ]]
# min-max range: 0.004337502643465996-0.9993957877159119

# %%
plot_power_spectra(ps10_noisesub, ks10sn_bin, params10sn, psn_bin[0], 0, showplots=True, saveplots=False, markers=True, label='after subtracting a random single line of noise, at logfX=-1.0')
plot_power_spectra(ps10_noisesub_b10, ks10sn_bin, params10sn, psn_bin_b10[0], 0, showplots=True, saveplots=False, markers=True, label='after subtracting a random single line of noise, at logfX=-1.0')
plot_power_spectra(ps10_noisesub, ks10sn_bin, params10sn, psn_bin[200], 0, showplots=True, saveplots=False, markers=True, label='after subtracting a random single line of noise, at logfX=-1.0')
plot_power_spectra(ps10_noisesub_b10, ks10sn_bin, params10sn, psn_bin_b10[20], 0, showplots=True, saveplots=False, markers=True, label='after subtracting a random single line of noise, at logfX=-1.0')
plot_power_spectra(ps10_noisesub, ks10sn_bin, params10sn, psn_bin[800], 0, showplots=True, saveplots=False, markers=True, label='after subtracting a random single line of noise, at logfX=-1.0')
plot_power_spectra(ps10_noisesub_b10, ks10sn_bin, params10sn, psn_bin_b10[80], 0, showplots=True, saveplots=False, markers=True, label='after subtracting a random single line of noise, at logfX=-1.0')
plot_power_spectra(ps10_noisesub_mean, ks10sn_bin, params10sn, psn_bin_mean, 0, showplots=True, saveplots=False, markers=True, label='after subtracting a random single line of noise, at logfX=-1.0')
# Out:
# ps.shape=(21, 16), ks.shape=(21, 16), paramas.shape=(21, 2)
# Params: (21, 2)
# Params: [[ 0.30353674 -1.        ]
#  [ 0.25006887 -1.        ]]
# min-max range: 0.004162702709436417-0.9957664012908936
# ps.shape=(21, 16), ks.shape=(21, 16), paramas.shape=(21, 2)
# Params: (21, 2)
# Params: [[ 0.30353674 -1.        ]
#  [ 0.25006887 -1.        ]]
# min-max range: 0.004162702709436417-0.9957664012908936
# ps.shape=(21, 16), ks.shape=(21, 16), paramas.shape=(21, 2)
# Params: (21, 2)
# Params: [[ 0.30353674 -1.        ]
#  [ 0.25006887 -1.        ]]
# min-max range: 0.004162702709436417-0.9957664012908936
# ps.shape=(21, 16), ks.shape=(21, 16), paramas.shape=(21, 2)
# Params: (21, 2)
# Params: [[ 0.30353674 -1.        ]
#  [ 0.25006887 -1.        ]]
# min-max range: 0.004162702709436417-0.9957664012908936
# ps.shape=(21, 16), ks.shape=(21, 16), paramas.shape=(21, 2)
# Params: (21, 2)
# Params: [[ 0.30353674 -1.        ]
#  [ 0.25006887 -1.        ]]
# min-max range: 0.004162702709436417-0.9957664012908936
# ps.shape=(21, 16), ks.shape=(21, 16), paramas.shape=(21, 2)
# Params: (21, 2)
# Params: [[ 0.30353674 -1.        ]
#  [ 0.25006887 -1.        ]]
# min-max range: 0.004162702709436417-0.9957664012908936
# ps.shape=(21, 16), ks.shape=(21, 16), paramas.shape=(21, 2)
# Params: (21, 2)
# Params: [[ 0.30353674 -1.        ]
#  [ 0.25006887 -1.        ]]
# min-max range: 0.004162702709436417-0.9957664012908936

# %%
# Noise subtraction
def noise_sub(ps_sn, ks, psn, ps_so, index, title):
    ps_noisesub = ps_sn - psn[index]
    ps_set1 = np.array([ps_noisesub[index,:], ps_sn[index,:], ps_so[index,:], psn[index,:]])
    labels=np.array(['Noise subtracted signal', 'Noisy signal', 'Pure signal', 'Noise'])
    plot(ps_set1, ks, title=title, labels=labels)

noise_sub(ps10sn_bin, ks10sn_bin, psn_bin, ps10so_bin, 0, title=f'Noise subtraction: random single noise line, at xHI={params10sn[0,0]:.2f} logfX={params10sn[0,1]:.2f}')
noise_sub(ps10sn_bin, ks10sn_bin, psn_bin, ps10so_bin, 10, title=f'Noise subtraction: random single noise line, at xHI={params10sn[10,0]:.2f} logfX={params10sn[10,1]:.2f}')
noise_sub(ps10sn_bin, ks10sn_bin, psn_bin, ps10so_bin, 20, title=f'Noise subtraction: random single noise line, at xHI={params10sn[20,0]:.2f} logfX={params10sn[20,1]:.2f}')
noise_sub(ps20sn_bin, ks20sn_bin, psn_bin, ps20so_bin, 0, title=f'Noise subtraction: random single noise line, at xHI={params20sn[0,0]:.2f} logfX={params20sn[0,1]:.2f}')
noise_sub(ps20sn_bin, ks20sn_bin, psn_bin, ps20so_bin, 10, title=f'Noise subtraction: random single noise line, at xHI={params20sn[10,0]:.2f} logfX={params20sn[10,1]:.2f}')
noise_sub(ps20sn_bin, ks20sn_bin, psn_bin, ps20so_bin, 20, title=f'Noise subtraction: random single noise line, at xHI={params20sn[20,0]:.2f} logfX={params20sn[20,1]:.2f}')
# Out:
# shapes: (4, 16),(21, 16)
# shapes: (4, 16),(21, 16)
# shapes: (4, 16),(21, 16)
# shapes: (4, 16),(21, 16)
# shapes: (4, 16),(21, 16)
# shapes: (4, 16),(21, 16)

# %%
def plot_mean_with_std(ps, ks, color='blue', label=''):
    mean_ps = np.mean(ps, axis=0)
    std_ps = np.std(ps, axis=0)

    plt.plot(ks[1:] * 1e6, mean_ps[1:], color=color, label=label, alpha=0.6, linewidth=2)

    # Shaded regions for 1 and 2 standard deviations
    plt.fill_between(ks[1:] * 1e6, mean_ps[1:] - std_ps[1:], mean_ps[1:] + std_ps[1:], color=color, alpha=0.3)
    plt.fill_between(ks[1:] * 1e6, mean_ps[1:] - 2*std_ps[1:], mean_ps[1:] + 2*std_ps[1:], color=color, alpha=0.1)

# %%
params10so_a, freq10so_a, los10so_a, ps10so_a, ks10so_a = load_dataset(["../data/21cmFAST_los/F21_noisy/F21_signalonly_21cmFAST_200Mpc_z6.0_fX-1.00_xHI0.52_8kHz.dat"], psbatchsize=10, limitsamplesize=None, ps_bins=None)
ks10so_bin_a, ps10so_bin_a = logbin_power_spectrum_by_k(ks10so_a, ps10so_a)

params10sn_a, freq10sn_a, los10sn_a, ps10sn_a, ks10sn_a = load_dataset(["../data/21cmFAST_los/F21_noisy/F21_noisy_21cmFAST_200Mpc_z6.0_fX-1.00_xHI0.52_uGMRT_8kHz_t500h_Smin64.2mJy_alphaR-0.44.dat"], psbatchsize=10, limitsamplesize=None, ps_bins=None)
ks10sn_bin_a, ps10sn_bin_a = logbin_power_spectrum_by_k(ks10sn_a, ps10sn_a)

ps10noisesub_bin_a = ps10sn_bin_a - psn_bin_mean

base.initplt()

plt.plot(ks10sn_bin_a[0,1:] * 1e6, psn_bin_mean[1:], "r--", label='Mean Noise', alpha=0.6, linewidth=2)

plot_mean_with_std(ps10sn_bin_a, ks10sn_bin_a[0], 'brown', label='Noisy signal')
plot_mean_with_std(ps10noisesub_bin_a, ks10sn_bin_a[0], 'blue', 'Noise subtracted')
plot_mean_with_std(ps10so_bin_a, ks10sn_bin_a[0], 'green', 'Actual signal')
#plot_mean_with_std(psn_bin, ks10sn_bin_a[0], 'red')
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'k (Hz$^{-1}$)')
plt.ylabel(r'$kP_{21}$')
plt.title('PS at logfx=-1.0 xHI=0.52')
plt.legend(fontsize=18)
plt.show()
# Out:
# \Loaded LoS data shape: (100, 2762)
# Loaded data: parameters shape: (100, 2)
# logbin_power_spectrum_by_k: original ks: [0.00000000e+00 2.84444178e-07 5.68888357e-07 8.53332535e-07
#  1.13777671e-06] .. [0.00039168 0.00039196 0.00039225 0.00039253 0.00039282]
# original ps: [0.00000000e+00 5.20659971e-09 1.98798267e-08 2.36932439e-08
#  4.63186903e-08]..[9.57047268e-08 7.96197685e-08 1.07784821e-07 8.28898760e-08
#  4.95240586e-08]
# [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06 1.77827941e-06 3.16227766e-06 5.62341325e-06
#  1.00000000e-05 1.77827941e-05 3.16227766e-05 5.62341325e-05
#  1.00000000e-04 1.77827941e-04 3.16227766e-04 5.62341325e-04]
# logbin_power_spectrum_by_k: final ks: [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06]..[5.62341325e-05 1.00000000e-04 1.77827941e-04 3.16227766e-04
#  5.62341325e-04]
# final ps: [0.00000000e+00 0.00000000e+00 5.20659971e-09 1.98798267e-08
#  3.50059671e-08]..[1.18323982e-07 1.23887095e-07 1.04697562e-07 8.42226841e-08
#  0.00000000e+00]
# \Loaded LoS data shape: (100, 2762)
# Loaded data: parameters shape: (100, 2)
# logbin_power_spectrum_by_k: original ks: [0.00000000e+00 2.84444178e-07 5.68888357e-07 8.53332535e-07
#  1.13777671e-06] .. [0.00039168 0.00039196 0.00039225 0.00039253 0.00039282]
# original ps: [0.00000000e+00 3.69453263e-08 1.14336708e-07 1.39052326e-07
#  1.03171887e-07]..[6.00397458e-05 2.93458582e-05 5.22100403e-05 8.72779382e-05
#  5.07799197e-05]
# [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06 1.77827941e-06 3.16227766e-06 5.62341325e-06
#  1.00000000e-05 1.77827941e-05 3.16227766e-05 5.62341325e-05
#  1.00000000e-04 1.77827941e-04 3.16227766e-04 5.62341325e-04]
# logbin_power_spectrum_by_k: final ks: [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06]..[5.62341325e-05 1.00000000e-04 1.77827941e-04 3.16227766e-04
#  5.62341325e-04]
# final ps: [0.00000000e+00 0.00000000e+00 3.69453263e-08 1.14336708e-07
#  1.21112106e-07]..[7.02352127e-06 1.14940553e-05 2.08659898e-05 3.61000240e-05
#  0.00000000e+00]

# %%
params10so_a, freq10so_a, los10so_a, ps10so_a, ks10so_a = load_dataset(["../data/21cmFAST_los/F21_noisy/F21_signalonly_21cmFAST_200Mpc_z6.0_fX-1.00_xHI0.25_8kHz.dat"], psbatchsize=10, limitsamplesize=None, ps_bins=None)
ks10so_bin_a, ps10so_bin_a = logbin_power_spectrum_by_k(ks10so_a, ps10so_a)

params10sn_a, freq10sn_a, los10sn_a, ps10sn_a, ks10sn_a = load_dataset(["../data/21cmFAST_los/F21_noisy/F21_noisy_21cmFAST_200Mpc_z6.0_fX-1.00_xHI0.25_uGMRT_8kHz_t500h_Smin64.2mJy_alphaR-0.44.dat"], psbatchsize=10, limitsamplesize=None, ps_bins=None)
ks10sn_bin_a, ps10sn_bin_a = logbin_power_spectrum_by_k(ks10sn_a, ps10sn_a)

ps10noisesub_bin_a = ps10sn_bin_a - psn_bin_mean

base.initplt()
plot_mean_with_std(ps10sn_bin_a, ks10sn_bin_a[0], 'brown', label='Noisy signal')
plot_mean_with_std(ps10noisesub_bin_a, ks10sn_bin_a[0], 'blue', 'Noise subtracted')
plot_mean_with_std(ps10so_bin_a, ks10sn_bin_a[0], 'green', 'Actual signal')
#plot_mean_with_std(psn_bin, ks10sn_bin_a[0], 'red')
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'k (Hz$^{-1}$)')
plt.ylabel(r'$kP_{21}$')
plt.title('PS at logfx=-1.0 xHI=0.25')
plt.legend()
plt.show()
# Out:
# \Loaded LoS data shape: (100, 2762)
# Loaded data: parameters shape: (100, 2)
# logbin_power_spectrum_by_k: original ks: [0.00000000e+00 2.84444178e-07 5.68888357e-07 8.53332535e-07
#  1.13777671e-06] .. [0.00039168 0.00039196 0.00039225 0.00039253 0.00039282]
# original ps: [0.00000000e+00 3.22238865e-09 5.90462046e-09 7.70378596e-09
#  2.06206107e-08]..[1.17019596e-08 1.10426587e-08 1.15215794e-08 1.79468709e-08
#  2.19383506e-08]
# [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06 1.77827941e-06 3.16227766e-06 5.62341325e-06
#  1.00000000e-05 1.77827941e-05 3.16227766e-05 5.62341325e-05
#  1.00000000e-04 1.77827941e-04 3.16227766e-04 5.62341325e-04]
# logbin_power_spectrum_by_k: final ks: [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06]..[5.62341325e-05 1.00000000e-04 1.77827941e-04 3.16227766e-04
#  5.62341325e-04]
# final ps: [0.00000000e+00 0.00000000e+00 3.22238865e-09 5.90462046e-09
#  1.41621983e-08]..[2.33533778e-08 2.38050421e-08 2.21945252e-08 1.65898314e-08
#  0.00000000e+00]
# \Loaded LoS data shape: (100, 2762)
# Loaded data: parameters shape: (100, 2)
# logbin_power_spectrum_by_k: original ks: [0.00000000e+00 2.84444178e-07 5.68888357e-07 8.53332535e-07
#  1.13777671e-06] .. [0.00039168 0.00039196 0.00039225 0.00039253 0.00039282]
# original ps: [0.00000000e+00 4.89033584e-08 5.85798020e-08 7.46581161e-08
#  8.55127860e-08]..[5.14339479e-05 4.17569290e-05 2.93723490e-05 3.76585104e-05
#  4.02906302e-05]
# [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06 1.77827941e-06 3.16227766e-06 5.62341325e-06
#  1.00000000e-05 1.77827941e-05 3.16227766e-05 5.62341325e-05
#  1.00000000e-04 1.77827941e-04 3.16227766e-04 5.62341325e-04]
# logbin_power_spectrum_by_k: final ks: [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06]..[5.62341325e-05 1.00000000e-04 1.77827941e-04 3.16227766e-04
#  5.62341325e-04]
# final ps: [0.00000000e+00 0.00000000e+00 4.89033584e-08 5.85798020e-08
#  8.00854511e-08]..[6.57561622e-06 1.17790765e-05 2.10450549e-05 3.61791975e-05
#  0.00000000e+00]

# %%
params10so_a, freq10so_a, los10so_a, ps10so_a, ks10so_a = load_dataset(["../data/21cmFAST_los/F21_noisy/F21_signalonly_21cmFAST_200Mpc_z6.0_fX-1.00_xHI0.11_8kHz.dat"], psbatchsize=10, limitsamplesize=None, ps_bins=None)
ks10so_bin_a, ps10so_bin_a = logbin_power_spectrum_by_k(ks10so_a, ps10so_a)

params10sn_a, freq10sn_a, los10sn_a, ps10sn_a, ks10sn_a = load_dataset(["../data/21cmFAST_los/F21_noisy/F21_noisy_21cmFAST_200Mpc_z6.0_fX-1.00_xHI0.11_uGMRT_8kHz_t500h_Smin64.2mJy_alphaR-0.44.dat"], psbatchsize=10, limitsamplesize=None, ps_bins=None)
ks10sn_bin_a, ps10sn_bin_a = logbin_power_spectrum_by_k(ks10sn_a, ps10sn_a)

ps10noisesub_bin_a = ps10sn_bin_a - psn_bin_mean

base.initplt()
plot_mean_with_std(ps10sn_bin_a, ks10sn_bin_a[0], 'brown', label='Noisy signal')
plot_mean_with_std(ps10noisesub_bin_a, ks10sn_bin_a[0], 'blue', 'Noise subtracted')
plot_mean_with_std(ps10so_bin_a, ks10sn_bin_a[0], 'green', 'Actual signal')
#plot_mean_with_std(psn_bin, ks10sn_bin_a[0], 'red')
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'k (Hz$^{-1}$)')
plt.ylabel(r'$kP_{21}$')
plt.title('PS at logfx=-1.0 xHI=0.11')
plt.legend()
plt.show()
# Out:
# \Loaded LoS data shape: (100, 2762)
# Loaded data: parameters shape: (100, 2)
# logbin_power_spectrum_by_k: original ks: [0.00000000e+00 2.84444178e-07 5.68888357e-07 8.53332535e-07
#  1.13777671e-06] .. [0.00039168 0.00039196 0.00039225 0.00039253 0.00039282]
# original ps: [0.00000000e+00 1.54190095e-09 2.19364216e-09 4.41921702e-09
#  5.85812812e-09]..[8.14235694e-09 7.29290013e-09 1.92579096e-09 5.15073862e-09
#  1.04807032e-08]
# [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06 1.77827941e-06 3.16227766e-06 5.62341325e-06
#  1.00000000e-05 1.77827941e-05 3.16227766e-05 5.62341325e-05
#  1.00000000e-04 1.77827941e-04 3.16227766e-04 5.62341325e-04]
# logbin_power_spectrum_by_k: final ks: [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06]..[5.62341325e-05 1.00000000e-04 1.77827941e-04 3.16227766e-04
#  5.62341325e-04]
# final ps: [0.00000000e+00 0.00000000e+00 1.54190095e-09 2.19364216e-09
#  5.13867257e-09]..[9.85315716e-09 7.76961758e-09 7.38197294e-09 4.80604855e-09
#  0.00000000e+00]
# \Loaded LoS data shape: (100, 2762)
# Loaded data: parameters shape: (100, 2)
# logbin_power_spectrum_by_k: original ks: [0.00000000e+00 2.84444178e-07 5.68888357e-07 8.53332535e-07
#  1.13777671e-06] .. [0.00039168 0.00039196 0.00039225 0.00039253 0.00039282]
# original ps: [0.00000000e+00 1.42014137e-08 6.71670909e-08 9.87419985e-08
#  1.22597757e-07]..[7.37766311e-05 3.64628340e-05 4.23540604e-05 3.12997105e-05
#  8.92661398e-05]
# [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06 1.77827941e-06 3.16227766e-06 5.62341325e-06
#  1.00000000e-05 1.77827941e-05 3.16227766e-05 5.62341325e-05
#  1.00000000e-04 1.77827941e-04 3.16227766e-04 5.62341325e-04]
# logbin_power_spectrum_by_k: final ks: [1.00000000e-07 1.77827941e-07 3.16227766e-07 5.62341325e-07
#  1.00000000e-06]..[5.62341325e-05 1.00000000e-04 1.77827941e-04 3.16227766e-04
#  5.62341325e-04]
# final ps: [0.00000000e+00 0.00000000e+00 1.42014137e-08 6.71670909e-08
#  1.10669878e-07]..[6.39207960e-06 1.17161369e-05 2.05753170e-05 3.60598814e-05
#  0.00000000e+00]
